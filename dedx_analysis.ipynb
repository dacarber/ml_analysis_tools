# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.express as px
import seaborn

# %%
electrons10 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_electrons.csv')
photons10 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_photons.csv')
electrons11 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r11_c2_lane_electrons.csv')
photons11 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r11_c2_lane_photons.csv')
electrons12 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r12_c2_lane_electrons.csv')
photons12 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r12_c2_lane_photons.csv')
electrons13 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r13_c2_lane_electrons.csv')
photons13 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r13_c2_lane_photons.csv')
electrons14 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r14_c2_lane_electrons.csv')
photons14 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r14_c2_lane_photons.csv')
electrons15 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r15_c2_lane_electrons.csv')
#photons15 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r15_c2_lane_photons.csv')

print(len(electrons10["electrons"])/(len(electrons10["electrons"])+len(photons10["photons"])))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 electrons10 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_electrons.csv')
#       2 photons10 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_photons.csv')
#       3 electrons11 = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r11_c2_lane_electrons.csv')
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
electron = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_electrons.csv')
photon = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_photons.csv')
#true = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_no_circle_v2_6_true_test.csv')
reco = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_reco.csv')
total = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total.csv')
total_p = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_total_p.csv')
total_e = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_total_e.csv')
#total_hits = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total_hits.csv')
true_electron = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_true_e.csv')
true_photon = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_true_p.csv')
#true = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_no_circle_v2_6_true_test.csv')
true = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_reco_true.csv')
true_total = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total_true.csv')
true_total_p = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_true_total_p.csv')
true_total_e = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_true_total_e.csv')

#total_e = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_no_circle_v2_6_total_e_test.csv')
#true_electron = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_no_circle_v2_6_true_electrons.csv')
#true_photon = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_no_circle_v2_6_true_photons.csv')
#print(true_electron)

# %%
m_electron = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_electrons.csv')
m_photon = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_photons.csv')
#true = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_no_circle_v2_6_true_test.csv')
m_reco = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_reco.csv')
m_total = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total.csv')
m_total_p = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total_p.csv')
m_total_e = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total_e.csv')
#total_hits = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total_hits.csv')
m_true_electron = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_electrons_true.csv')
m_true_photon = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_photons_true.csv')
#true = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_c2_lane_no_circle_v2_6_true_test.csv')
m_true = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_reco_true.csv')
m_true_total = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total_true.csv')
m_true_total_p = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total_p_true.csv')
m_true_total_e = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_matched_numi_nue_total_e_true.csv')

# %%
con_total = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_con_total.csv')
con_total_p = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_con_total_p.csv')
con_total_e = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_con_total_e.csv')
true_total = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_total.csv')
start_x = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_start_x.csv')
start_y = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_start_y.csv')
start_z = pd.read_csv(r'/sdf/home/d/dcarber/data/data_r10_NuMI_nue_start_z.csv')

# %%
sel10 = []
total_list10 = []
selection10 = 0
old_sum10  = 0

for i in range(0,1000,1):
    k10 = i /100
    e_mask = []
    p_mask= []
    for e in range(len(electrons10["electrons"])):
        if electrons10["electrons"][e] < k10:
            e_mask.append(True)
        else:
            e_mask.append(False)
    for p in range(len(photons10["photons"])):
        if photons10["photons"][p] >  k10:
            p_mask.append(True)
        else:
            p_mask.append(False)
    total10 = (np.sum(e_mask)/len(electrons10["electrons"]) + np.sum(p_mask)/len(photons10["photons"]))/2
    if total10 > old_sum10:
        selection10 = k10
        old_sum10 = total10
    sel10.append(k10)
    total_list10.append(total10)
    
print(f"line spot: {selection10} and total: {old_sum10} ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       8 e_mask = []
#       9 p_mask= []
# ---> 10 for e in range(len(electrons10["electrons"])):
#      11     if electrons10["electrons"][e] < k10:
#      12         e_mask.append(True)
#
# NameError: name 'electrons10' is not defined

# %%
sel11 = []
total_list11 = []
selection11 = 0
old_sum11  = 0

for i in range(0,1000,1):
    k11 = i /100
    e_mask = []
    p_mask= []
    for e in range(len(electrons11["electrons"])):
        if electrons11["electrons"][e] < k11:
            e_mask.append(True)
        else:
            e_mask.append(False)
    for p in range(len(photons11["photons"])):
        if photons11["photons"][p] >  k11:
            p_mask.append(True)
        else:
            p_mask.append(False)
    total11 = (np.sum(e_mask)/len(electrons11["electrons"]) + np.sum(p_mask)/len(photons11["photons"]))/2
    if total11 > old_sum11:
        selection11 = k11
        old_sum11 = total11
    sel11.append(k11)
    total_list11.append(total11)
    
print(f"line spot: {selection11} and total: {old_sum11} ")
# Out:
# line spot: 3.65 and total: 0.757045217676136

# %%
sel12 = []
total_list12 = []
selection12 = 0
old_sum12  = 0

for i in range(0,1000,1):
    k12 = i /100
    e_mask = []
    p_mask= []
    for e in range(len(electrons12["electrons"])):
        if electrons12["electrons"][e] < k12:
            e_mask.append(True)
        else:
            e_mask.append(False)
    for p in range(len(photons12["photons"])):
        if photons12["photons"][p] >  k12:
            p_mask.append(True)
        else:
            p_mask.append(False)
    total12 = (np.sum(e_mask)/len(electrons12["electrons"]) + np.sum(p_mask)/len(photons12["photons"]))/2
    if total12 > old_sum12:
        selection12 = k12
        old_sum12 = total12
    sel12.append(k12)
    total_list12.append(total12)
    
print(f"line spot: {selection12} and total: {old_sum12} ")
# Out:
# line spot: 3.67 and total: 0.7527502067824648

# %%
sel13 = []
total_list13 = []
selection13 = 0
old_sum13  = 0

for i in range(0,1000,1):
    k13 = i /100
    e_mask = []
    p_mask= []
    for e in range(len(electrons13["electrons"])):
        if electrons13["electrons"][e] < k13:
            e_mask.append(True)
        else:
            e_mask.append(False)
    for p in range(len(photons13["photons"])):
        if photons13["photons"][p] >  k13:
            p_mask.append(True)
        else:
            p_mask.append(False)
    total13 = (np.sum(e_mask)/len(electrons13["electrons"]) + np.sum(p_mask)/len(photons13["photons"]))/2
    if total13 > old_sum13:
        selection13 = k13
        old_sum13 = total13
    sel13.append(k13)
    total_list13.append(total13)
    
print(f"line spot: {selection13} and total: {old_sum13} ")
# Out:
# line spot: 3.61 and total: 0.7509661460814947

# %%
sel14 = []
total_list14 = []
selection14 = 0
old_sum14  = 0

for i in range(0,1000,1):
    k14 = i /100
    e_mask = []
    p_mask= []
    for e in range(len(electrons14["electrons"])):
        if electrons14["electrons"][e] < k14:
            e_mask.append(True)
        else:
            e_mask.append(False)
    for p in range(len(photons14["photons"])):
        if photons14["photons"][p] >  k14:
            p_mask.append(True)
        else:
            p_mask.append(False)
    total14 = (np.sum(e_mask)/len(electrons14["electrons"]) + np.sum(p_mask)/len(photons14["photons"]))/2
    if total14 > old_sum14:
        selection14 = k14
        old_sum14 = total14
    sel14.append(k14)
    total_list14.append(total14)
    
print(f"line spot: {selection14} and total: {old_sum14} ")
# Out:
# line spot: 3.55 and total: 0.7468798574989769

# %%
sel15 = []
total_list15 = []
selection15 = 0
old_sum15  = 0

for i in range(0,1000,1):
    k15 = i /100
    e_mask = []
    p_mask= []
    for e in range(len(electrons15["electrons"])):
        if electrons15["electrons"][e] < k15:
            e_mask.append(True)
        else:
            e_mask.append(False)
    for p in range(len(photons15["photons"])):
        if photons15["photons"][p] >  k15:
            p_mask.append(True)
        else:
            p_mask.append(False)
    total15 = (np.sum(e_mask)/len(electrons15["electrons"]) + np.sum(p_mask)/len(photons15["photons"]))/2
    if total15 > old_sum15:
        selection15 = k15
        old_sum15 = total15
    sel15.append(k15)
    total_list15.append(total15)
    
print(f"line spot: {selection15} and total: {old_sum15} ")
# Out:
# line spot: 3.61 and total: 0.7439931607821246

# %%
seaborn.set(rc={
    'figure.figsize':(15, 10),
})
seaborn.set_context('talk')
plt.plot(sel10,total_list10,color = "red")
plt.axvline(x=selection10,color = "red", label = f"10 Voxel, Cutoff: {selection10} , and Accuracy: {old_sum10:4f}")
plt.plot(sel11,total_list11,color = "green")
plt.axvline(x=selection11,color = "green", label = f"11 Voxel, Cutoff: {selection11} , and Accuracy: {old_sum11:4f}")
plt.plot(sel12,total_list12,color = "orange")
plt.axvline(x=selection12,color = "orange", label = f"12 Voxel, Cutoff: {selection12} , and Accuracy: {old_sum12:4f}")
plt.plot(sel13,total_list13,color = "purple")
plt.axvline(x=selection13,color = "purple", label = f"13 Voxel, Cutoff: {selection13} , and Accuracy: {old_sum13:4f}")
plt.plot(sel14,total_list14,color = "cyan")
plt.axvline(x=selection14,color = "cyan", label = f"14 Voxel, Cutoff: {selection14} , and Accuracy: {old_sum14:4f}")
plt.plot(sel15,total_list15,color = "black")
plt.axvline(x=selection15,color = "black", label = f"15 Voxel, Cutoff: {selection15} , and Accuracy {old_sum15:4f}")
plt.legend(loc = "upper right")
plt.xlabel("dE/dx [MeV/cm]")
plt.ylabel("Accurate selections")
plt.title("Accuracy of selection cut for dE/dx shower start ")
#plt.xlim([2, 6])
plt.show()
plt.savefig('Accuracy.png')

# %%
electron_mean = np.mean(electron["electrons"])
print(electron_mean)
# Out:
# 2.3917572560581934

# %%
seaborn.set(rc={
    'figure.figsize':(8, 6),
})
seaborn.set_context('talk')

#plt.hist(m_true_electron["electrons"], range=[0, 10],bins=50,alpha =1, label = "True Electrons Init")
plt.hist(m_true_photon["photons"], range=[0, 40], alpha = 1,bins=50,label = "True photons depo_MeV")
plt.hist(m_true["reco"], range=[0, 40],alpha = .6,bins=50, label = "True sum depo_MeV")
#plt.hist(m_electron["electrons"], range=[0, 10],bins=50, label = "Reco Electrons", alpha = .3)
#plt.hist(m_photon["photons"], range=[0, 10], alpha = .2,bins=50,label = "Reco Photons")
plt.hist(m_reco["reco"], range=[0, 40],alpha = .2,bins=50, label = "Reco")

#plt.hist(total_e["total_e"], range=[0, 700],bins=50, label = "Total")
#plt.hist(low_e["low_e"], range=[0, 700],bins=50, label = "Low dE/dx bump")
#plt.hist(true_electron["true_e"], range=[0, 10],bins=50, label = "Electrons")
#plt.hist(true_photon["true_p"], range=[0, 10], alpha = .6,bins=50,label = "Photons")
#plt.hist(true["true"], range=[0, 10],alpha = 1,bins=50, label = "True")
         
#plt.hist(true13["true"], range=[0, 10],alpha = .9,bins=50, label = "13 cm cut")
#plt.axvline(x = 1.9055, color = 'r',label = f'True MPV: 1.905 MeV/cm')
#plt.axvline(x = 2.2175, color = 'y',label = f'True Mean: 2.2175 MeV/cm')
#plt.axvline(x = 2.4256, color = 'g',label = f'Calc Mean: 2.4256 MeV/cm')
plt.legend(loc = "upper right")
plt.xlabel("Voxels")
plt.xlabel("dE [MeV]")
#plt.ylabel("Showers")
plt.title("Shower reco dE and depo_MeV")
plt.show()
plt.savefig('dedx_4000_events.png')

# %%
plt.hist(true_total["total"], range=[10, 2000],bins=60, label = "True")
plt.hist(con_total["contain"], range=[10, 2000],bins=60, label = "Reco",alpha = .6)
#plt.hist(true_total["total"], range=[0, 750],bins=60, label = "Electrons",alpha = .2)
plt.legend(loc = "upper right")
plt.xlabel("Energy [MeV]")
plt.ylabel("Showers")
plt.title("Reco total shower energy ")
plt.show()
plt.savefig('dedx_4000_events.png')

# %%
def abline(slope, intercept):
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '-')

# %%
#print(len(m_true_electron["electrons"]), len(m_electron["electrons"]))
plt.hist2d(m_true["reco"], m_reco["reco"],range = [[0, 30], [0, 100]], bins = [100,100],cmap=plt.cm.jet)
plt.xlabel("True dE of shower start [MeV]")
plt.ylabel("Reco dE of shower start [MeV]")
plt.title("Reco vs Depo_MeV Energy")
abline(1,0)
plt.colorbar()  
plt.show()
plt.savefig('dedx_true_reco_diff_4000_events.png')

# %%
con_diff = true_total["total"]-con_total["contain"]
mask = con_diff != 0
plt.hist(con_diff[mask], range=[-500, 2000],bins=60, label = "True")
plt.legend(loc = "upper right")
plt.xlabel("Energy [MeV]")
plt.ylabel("Showers")
plt.title("Reco total shower energy ")
plt.show()
plt.savefig('dedx_4000_events.png')

# %%
print(len(m_true_electron["electrons"]), len(m_electron["electrons"]))
plt.hist2d(start_y["y"][mask], con_diff[mask],range = [[-100, 1500], [-1000, 5000]], bins = [100,100],cmap=plt.cm.jet)
plt.xlabel("Startpoint position [MeV]")
plt.ylabel("Difference between contained and total [MeV]")
plt.title("No_ghost vs Depo_MeV Energy")
abline(1,0)
plt.colorbar()  
plt.show()
plt.savefig('dedx_true_reco_diff_4000_events.png')
# Out:
# 5581 5581

# %%
diff = []
std =[]
x_axis = []
x_bins = 200
num =0
diff = (np.subtract(m_reco["reco"],m_true["reco"]))/m_true["reco"]
fig = plt.subplots(figsize =(10, 7))
#fig = plt.figure()
#gs = fig.add_gridspec(2, hspace=0)
#axs = gs.subplots(sharex=True, sharey=True)
#plot2 = plt.hist2d(x,y,range = [[0, 1.25], [0, 1.25]], bins = [20,20])
'''
for i in range(x_bins):
    values = []
    for t in range(len(m_true_total_e["total_e"])):
        num =m_true_total_e["total_e"][t]
        if num>=i*100 and num<(i+1)*100:
            values.append(diff[t])
    std.append(np.std(values))
    x_axis.append(i*100)
    #print(std)
'''
#plot2 = plt.scatter(x_axis,std)
plot1 = plt.hist2d(m_true["reco"], diff,range = [[0, 10], [-2, 2]], bins = [x_bins,100],cmap=plt.cm.jet)

     
    
#plt.title("True Shower Start vs. Reco Shower Start")
plt.xlabel("True dE/dx [MeV/cm]")
plt.ylabel("(Reco - True)/True")
plt.title("6500 Events")
plt.colorbar()  
# show plot
plt.show()
plt.savefig('dedx_true_reco_diff_4000_events.png')

# %%
diff = []
std =[]
x_axis = []
x_bins = 20
num =0
diff = (np.subtract(m_total_e["total_e"],m_true_total_e["total_e"]))/m_true_total_e["total_e"]
#fig,ax = plt.subplots(figsize =(10, 7))
fig, ax1 = plt.subplots(2, 1, sharex=True)
#fig = plt.figure()
#gs = fig.add_gridspec(2, hspace=0)
#axs = gs.subplots(sharex=True, sharey=True)
#plot2 = plt.hist2d(x,y,range = [[0, 1.25], [0, 1.25]], bins = [20,20])

for i in range(x_bins):
    values = []
    for t in range(len(m_true_total_e["total_e"])):
        num =m_true_total_e["total_e"][t]
        if num>=i*100 and num<(i+1)*100:
            values.append(diff[t])
    std.append(np.std(values))
    x_axis.append(i*100)
    #print(std)

#
plt.subplot(1,1,1)

plot1 = plt.hist2d(m_true_total_e["total_e"], diff,range = [[0, 2000], [-1, 1]], bins = [x_bins,100],cmap=plt.cm.jet)

     
  
plt.title("True Shower Start vs. Reco Shower Start")
plt.xlabel("True Energy depo_MeV [MeV]")
plt.ylabel("(Reco - True)/True")
plt.title("Bias of true depo_MeV and Reco")
plt.colorbar()  

plt.subplot(2,1,2)
plot2 = plt.scatter(x_axis,std)

plt.ylim(0, 1)
#ax1.xlabel("True Energy depo_MeV [MeV]")
plt.ylabel("RMS")
plt.title("Bias of true depo_MeV and Reco")

# show plot
plt.show()
plt.savefig('dedx_true_reco_diff_4000_events.png')
# Out:
# /tmp/ipykernel_15156/3255574617.py:25: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,1,1)
# /tmp/ipykernel_15156/3255574617.py:37: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,1,2)

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')

# Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')

# Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')

# Note that this is the same as
plt.subplots(2, 2, sharex=True, sharey=True)

# Create figure number 10 with a single subplot
# and clears it if it already exists.
fig, ax = plt.subplots(num=10, clear=True)

# %%
diff = []
std =[]
x_axis = []
x_bins = 20
num =0
diff = (np.subtract(m_total_e["total_e"],m_true_total_e["total_e"]))/m_true_total_e["total_e"]
fig = plt.subplots(figsize =(10, 7))
#fig = plt.figure()
#gs = fig.add_gridspec(2, hspace=0)
#axs = gs.subplots(sharex=True, sharey=True)
#plot2 = plt.hist2d(x,y,range = [[0, 1.25], [0, 1.25]], bins = [20,20])
for i in range(x_bins):
    values = []
    for t in range(len(m_true_total_e["total_e"])):
        num =m_true_total_e["total_e"][t]
        if num>=i*100 and num<(i+1)*100:
            values.append(diff[t])
    std.append(np.std(values))
    x_axis.append(i*100)
    #print(std)
plot2 = plt.scatter(x_axis,std)
#plot1 = plt.hist2d(m_true_total_e["total_e"], diff,range = [[0, 2000], [-1, 1]], bins = [x_bins,100],cmap=plt.cm.jet)

     
    
#plt.title("True Shower Start vs. Reco Shower Start")
plt.xlim(10, 2000)
plt.ylim(0, 1)
plt.xlabel("True Energy depo_MeV [MeV]")
plt.ylabel("RMS")
plt.title("Bias of true depo_MeV and Reco")
#plt.colorbar()  
# show plot
plt.show()
plt.savefig('dedx_true_reco_diff_4000_events.png')
